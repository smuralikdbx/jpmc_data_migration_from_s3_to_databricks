# %%
import boto3
import os
import re
from pyspark.sql.types import StructType, StructField, StringType, LongType, TimestampType, IntegerType, DateType
from datetime import timezone
from pyspark.sql.functions import col, regexp_extract, lit, lower, count, sum, when, regexp_extract_all, size, array_join, current_timestamp, split, expr, concat
from delta.tables import DeltaTable
from pyspark.sql import functions as F

# %%
dbutils.widgets.text("catalog", "")
dbutils.widgets.text("schema", "")
dbutils.widgets.text("s3_inventory_table", "")
dbutils.widgets.text("candidate_table", "")
dbutils.widgets.text("dataset_mapping_file_location", "") 
dbutils.widgets.text("archive_dataset_mapping_file_location", "")
dbutils.widgets.text("dataset_mapping_table", "")
dbutils.widgets.text("job_id", "")
dbutils.widgets.text("run_id", "")
dbutils.widgets.text("dataset_mapping_file","")

catalog = dbutils.widgets.get("catalog")
schema = dbutils.widgets.get("schema")
s3_inventory_table = dbutils.widgets.get("s3_inventory_table")
candidate_table = dbutils.widgets.get("candidate_table")
dataset_mapping_file_location = dbutils.widgets.get("dataset_mapping_file_location")
archive_dataset_mapping_file_location= dbutils.widgets.get("archive_dataset_mapping_file_location")
dataset_mapping_table = dbutils.widgets.get("dataset_mapping_table")
job_id = dbutils.widgets.get("job_id")
run_id = dbutils.widgets.get("run_id")
dataset_mapping_file = dbutils.widgets.get("dataset_mapping_file")

execution_id = job_id + "-" + run_id
candidate_table = catalog + "." + schema + "." + candidate_table
s3_inventory_table = catalog + "." + schema + "." + s3_inventory_table
dataset_mapping_table = catalog + "." + schema + "." + dataset_mapping_table

# %%
from datetime import datetime

def list_s3_files_recursive(path,s3_bucket_name, bucket_prefix):
  all_files = []
  try:
      files = dbutils.fs.ls(path)
    #   print(path)
  except Exception as e:
      print(f"Error reading path {path}: {e}")
      return all_files

  for f in files:
      if f.path.endswith("/"): 
          all_files.extend(list_s3_files_recursive(f.path, s3_bucket_name, bucket_prefix))
      else:
          ext = f.name.split(".")[-1] if "." in f.name else None
          all_files.append({
              "execution_id": execution_id,
              "s3_bucket_name": s3_bucket_name,
              "bucket_prefix": bucket_prefix,
              "path": f.path,
              "file_name": f.name,
              "last_modified_time": datetime.fromtimestamp(f.modificationTime / 1000),
              "size": f.size,
              "extension": ext
          })
  return all_files

# %%
# if file_exists_in_volume(f"{dataset_mapping_file_location}/{dataset_mapping_file}"):
#   print("test")

# %%
dataset_mapping_schema = StructType([
    StructField("dataset_name", StringType(), True),
    StructField("s3_bucket_name", StringType(), True),
    StructField("bucket_prefix", StringType(), True),
    StructField("dbx_catalog", StringType(), True),
    StructField("dbx_managed_table_schema", StringType(), True),
    StructField("datetime", TimestampType(), True)
])

df_dataset_mapping = spark.createDataFrame([], dataset_mapping_schema)

def file_exists_in_volume(file_path: str) -> bool:
    try:
        # Split into folder and filename
        folder, file_name = file_path.rsplit("/", 1)
        files = dbutils.fs.ls(folder)
        return any(f.name == file_name for f in files)
    except Exception:
        return False


if file_exists_in_volume(f"{dataset_mapping_file_location}/{dataset_mapping_file}"):
    df_dataset_mapping = spark.read \
        .option("header", "true") \
        .schema(dataset_mapping_schema) \
        .csv(f"{dataset_mapping_file_location}/{dataset_mapping_file}")\
        .withColumn("datetime", current_timestamp())

    display(df_dataset_mapping)

    dataset_mapping_table = DeltaTable.forName(spark, dataset_mapping_table)

    dataset_mapping_insert_cols = ["dataset_name", "s3_bucket_name", "bucket_prefix", "dbx_catalog", "dbx_managed_table_schema", "datetime"]

    dataset_mapping_table.alias("t").merge(
        df_dataset_mapping.alias("s"),
        "t.dataset_name = s.dataset_name AND \
        t.s3_bucket_name = s.s3_bucket_name AND \
        t.bucket_prefix = s.bucket_prefix"
    ).whenNotMatchedInsert(values={col: f"s.{col}" for col in dataset_mapping_insert_cols}).execute()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dataset_name</th><th>s3_bucket_name</th><th>bucket_prefix</th><th>dbx_catalog</th><th>dbx_managed_table_schema</th><th>datetime</th></tr></thead><tbody><tr><td>lda_taser_txns_shrt_wndw_daily</td><td>app-id-89055-dep-id-109792-uu-id-n6ph64imx36e</td><td>trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/</td><td>89055_ctg_prod_exp</td><td> dbx_89055_trusted_db_mdas_ais_hcd_dora_fdl_prod_exp</td><td>2025-12-04T17:42:30.621505Z</td></tr></tbody></table></div>

# %%
from pyspark.sql import functions as F
from pyspark.sql.types import DateType


# final_file_list =[]
prefixes=[]
df_dataset_inventory= None
# for df in df_dataset_mapping.select("s3_bucket_name", "bucket_prefix").distinct().filter(F.col("bucket_prefix")== "trusted/fnce/data_insgts/cpb_acct/").collect():
for df in df_dataset_mapping.select("s3_bucket_name", "bucket_prefix").distinct().collect():
    
    try:
        print(f"Processing dataset: {df['bucket_prefix']}")
        path=f"s3://{df['s3_bucket_name']}/{df['bucket_prefix']}"
        file_list = list_s3_files_recursive(path,df['s3_bucket_name'],df['bucket_prefix'])

        #To consider incremental files from S3 
        s3_files_df=spark.createDataFrame(file_list)
        src_invtry_df=spark.sql(f"""
                            SELECT max(last_modified_time) FROM {s3_inventory_table} where bucket_prefix ="{df['bucket_prefix']}"
                        """)
        max_last_modfied_file_time=src_invtry_df.collect()[0][0]
        print(max_last_modfied_file_time)

        # s3_files_df.agg(F.max("last_modified_time").alias("max_value")).show()
        # print(s3_max_last_modified)

        if max_last_modfied_file_time:
            s3_files_df=s3_files_df.filter(col("last_modified_time")>max_last_modfied_file_time)
        else:
            s3_files_df
        print(s3_files_df.count())
        if s3_files_df.count() == 0:
            print(f"No new files to process for  {df['bucket_prefix']}")
            continue

        df_dataset_inventory=s3_files_df\
        .withColumn(
            "key", 
            expr("regexp_replace(path, concat('s3://', s3_bucket_name, '/'), '')")
        )

        df_dataset_inventory_filtered = df_dataset_inventory.alias("inventory") \
            .join(
                df_dataset_mapping.alias("mapping"),
                (col("inventory.s3_bucket_name") == col("mapping.s3_bucket_name")) &
                (col("inventory.bucket_prefix") == col("mapping.bucket_prefix")),
                "inner"  # inner join keeps only matches
            ) \
            .select("inventory.*")

        partition_expr = regexp_extract_all(lower(col("key")), lit(r"([a-zA-Z0-9_]+)="))

    # Convert array -> comma-separated string
        df_dataset_inventory_filtered = df_dataset_inventory_filtered\
                                        .withColumn("partition_key", when(size(partition_expr) > 0, array_join(partition_expr, ", ")).otherwise(lit(None)))\
                                        .withColumn("edp_run_id", F.regexp_extract(lower(F.col("key")),r"edp_run_id=([^/]+)",1))\
                                        .withColumn("snapshot_date", F.regexp_extract(lower(F.col("key")),r"snapshot_date=([^/]+)",1))

        
        df_dataset_inventory_filtered = df_dataset_inventory_filtered.select("execution_id", "s3_bucket_name", "bucket_prefix", "key","extension", "size", "last_modified_time","partition_key","edp_run_id","snapshot_date")

        df_dataset_inventory_filtered=df_dataset_inventory_filtered.withColumn("snapshot_date",col("snapshot_date").cast(DateType()))
        
        #display(df_dataset_inventory_filtered)
        
        #print(s3_inventory_table)
        df_dataset_inventory_filtered.write \
        .mode("append") \
        .format("delta") \
        .saveAsTable(s3_inventory_table)
        
        print(f"Processing dataset completed for: {df['bucket_prefix']}")
        prefixes.append(df['bucket_prefix'])
    except Exception as e:
        print(f"Error Processing dataset for {df['bucket_prefix']}")
        
if not prefixes:
    print("No new records for any of the datasets")
else:
    print(f"Inventory table processing completed for : {prefixes}")
    
#prefixes = [row.bucket_prefix for row in df_dataset_inventory_filtered.select("bucket_prefix").distinct().collect()]
#print(prefixes)
# Out:
# Processing dataset: trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=00429282-c29b-4958-b393-21278f03f198/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=00429282-c29b-4958-b393-21278f03f198/snapshot_date=2021-10-08/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=007bf865-f463-42e5-a4e1-7b1a5d9a9c87/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=007bf865-f463-42e5-a4e1-7b1a5d9a9c87/snapshot_date=2021-03-20/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0088db53-58dc-444f-afac-6ba19337a135/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0088db53-58dc-444f-afac-6ba19337a135/snapshot_date=2018-06-07/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0089f156-791f-43c5-8123-4a6cfce6a854/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0089f156-791f-43c5-8123-4a6cfce6a854/snapshot_date=2022-10-17/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=00a6d1ca-61d6-4f3b-8caf-c0361734f945/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=00a6d1ca-61d6-4f3b-8caf-c0361734f945/snapshot_date=2018-02-21/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=00c994e9-5ac2-46df-8717-b35ecf790ea1/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=00c994e9-5ac2-46df-8717-b35ecf790ea1/snapshot_date=2021-09-15/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=00edb549-5032-48f9-b126-4ec9642e8fa9/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=00edb549-5032-48f9-b126-4ec9642e8fa9/snapshot_date=2021-05-14/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=00f2e817-2e0e-4143-9784-83619f7bea09/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=00f2e817-2e0e-4143-9784-83619f7bea09/snapshot_date=2019-05-22/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=00ff9356-d6ae-4bad-b2b0-698d70aaa6a1/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=00ff9356-d6ae-4bad-b2b0-698d70aaa6a1/snapshot_date=2022-07-13/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=01031794-e5b8-4b41-a020-7cdfd1941f0a/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=01031794-e5b8-4b41-a020-7cdfd1941f0a/snapshot_date=2022-05-29/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=01132d4c-5233-494b-8b86-096d80b8d525/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=01132d4c-5233-494b-8b86-096d80b8d525/snapshot_date=2019-08-19/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0122a89a-97dd-4378-b34e-1ff30dc4c601/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0122a89a-97dd-4378-b34e-1ff30dc4c601/snapshot_date=2020-02-29/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=01318890-c274-48cd-9ed7-dbbf4ee98c77/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=01318890-c274-48cd-9ed7-dbbf4ee98c77/snapshot_date=2018-03-17/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=013aa150-ce8b-450c-8def-d0e6d0123c76/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=013aa150-ce8b-450c-8def-d0e6d0123c76/snapshot_date=2016-09-08/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0148160b-b0b0-4654-aee7-500825faf69e/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0148160b-b0b0-4654-aee7-500825faf69e/snapshot_date=2023-02-03/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0151060e-9e5a-4c20-9872-a85d3c3a14c4/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0151060e-9e5a-4c20-9872-a85d3c3a14c4/snapshot_date=2023-01-13/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=015585b3-18d8-40ca-b555-0882301c33c8/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=015585b3-18d8-40ca-b555-0882301c33c8/snapshot_date=2019-01-22/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=017938dd-4836-47c6-b17f-81dc6f52b8a9/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=017938dd-4836-47c6-b17f-81dc6f52b8a9/snapshot_date=2022-04-17/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=018279d0-45e7-444b-89f2-c472d6ed76e4/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=018279d0-45e7-444b-89f2-c472d6ed76e4/snapshot_date=2023-10-07/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=018b3e10-1494-4d2d-b45c-c385ba92cbfc/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=018b3e10-1494-4d2d-b45c-c385ba92cbfc/snapshot_date=2019-04-17/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=01adb8dd-d510-48bd-8f88-59333d217935/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=01adb8dd-d510-48bd-8f88-59333d217935/snapshot_date=2023-04-21/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=01bdd32c-18ed-4f91-8ea5-b20c150a7668/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=01bdd32c-18ed-4f91-8ea5-b20c150a7668/snapshot_date=2022-04-29/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=01bfeaa0-437f-4e3e-9f2e-5b33be8c38c4/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=01bfeaa0-437f-4e3e-9f2e-5b33be8c38c4/snapshot_date=2016-12-12/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=01c9dbfd-dac7-417c-a006-45c6213ee056/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=01c9dbfd-dac7-417c-a006-45c6213ee056/snapshot_date=2018-05-29/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=01e12aaa-2244-48d7-997e-340f9e7e3a8c/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=01e12aaa-2244-48d7-997e-340f9e7e3a8c/snapshot_date=2023-06-26/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0206c741-2bae-4efd-83e3-1101506c59f2/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0206c741-2bae-4efd-83e3-1101506c59f2/snapshot_date=2021-07-12/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=020a2ee1-4d38-4f3d-921f-03a852e444b6/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=020a2ee1-4d38-4f3d-921f-03a852e444b6/snapshot_date=2023-09-06/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=021be3b2-d3f7-4d20-ae0b-3c0ba12d8f9d/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=021be3b2-d3f7-4d20-ae0b-3c0ba12d8f9d/snapshot_date=2019-07-08/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0273985a-9dec-47c6-9b68-68f3f1d9fedc/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0273985a-9dec-47c6-9b68-68f3f1d9fedc/snapshot_date=2015-10-26/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=02908c11-9328-4a70-b2fb-b62ab5fd4897/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=02908c11-9328-4a70-b2fb-b62ab5fd4897/snapshot_date=2017-05-24/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0297ddc5-4319-4600-aef8-45cd260a77e2/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0297ddc5-4319-4600-aef8-45cd260a77e2/snapshot_date=2017-05-22/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=02da705d-813a-4891-bbcf-f7a336fb6570/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=02da705d-813a-4891-bbcf-f7a336fb6570/snapshot_date=2023-03-07/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=02ea2d89-cf28-4727-a08f-cca52414929b/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=02ea2d89-cf28-4727-a08f-cca52414929b/snapshot_date=2022-06-06/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=02ea90ae-7eb6-4f1d-bc2d-c85efe781fd0/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=02ea90ae-7eb6-4f1d-bc2d-c85efe781fd0/snapshot_date=2021-02-23/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=02ec46b0-e7f2-4ae9-9470-96a4a1cd91e4/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=02ec46b0-e7f2-4ae9-9470-96a4a1cd91e4/snapshot_date=2024-03-31/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0327881c-4d66-4293-a2b4-4650d98a21b0/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0327881c-4d66-4293-a2b4-4650d98a21b0/snapshot_date=2020-01-29/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0327d860-f407-48a3-a5e2-04174bd1c505/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0327d860-f407-48a3-a5e2-04174bd1c505/snapshot_date=2020-12-23/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0352559b-6cd2-485e-acbe-398a0039dd30/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0352559b-6cd2-485e-acbe-398a0039dd30/snapshot_date=2022-12-07/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=036f7a61-bb49-4ffe-8db1-066448f32bc8/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=036f7a61-bb49-4ffe-8db1-066448f32bc8/snapshot_date=2016-05-03/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=03739a0f-1607-4639-b422-1ba5c06b0fd3/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=03739a0f-1607-4639-b422-1ba5c06b0fd3/snapshot_date=2019-10-17/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=037999e6-0fcd-49ab-9d35-7a22f10293aa/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=037999e6-0fcd-49ab-9d35-7a22f10293aa/snapshot_date=2017-07-18/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0380b20f-c52c-49cd-b2b2-cf8160c08d18/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0380b20f-c52c-49cd-b2b2-cf8160c08d18/snapshot_date=2016-11-24/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0387e16a-066d-4475-87fb-a98a67cda7fd/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0387e16a-066d-4475-87fb-a98a67cda7fd/snapshot_date=2023-11-19/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=038ba1cd-7f76-4eba-a4c1-b14fd2115178/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=038ba1cd-7f76-4eba-a4c1-b14fd2115178/snapshot_date=2021-12-20/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=03971127-0044-435e-afca-36b2e4498181/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=03971127-0044-435e-afca-36b2e4498181/snapshot_date=2023-12-29/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=03c262e8-faa4-4669-99ca-952d986fdcff/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=03c262e8-faa4-4669-99ca-952d986fdcff/snapshot_date=2023-07-13/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=03c3ff39-e241-4e5b-88df-171e1e899dea/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=03c3ff39-e241-4e5b-88df-171e1e899dea/snapshot_date=2022-10-30/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=03c95e72-4c04-4b52-86f7-dee0275da3c5/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=03c95e72-4c04-4b52-86f7-dee0275da3c5/snapshot_date=2021-10-15/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=03e03705-9ead-40b1-8997-48e61f14364f/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=03e03705-9ead-40b1-8997-48e61f14364f/snapshot_date=2019-03-08/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0424a952-09b0-484d-9c9e-9756404c3123/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0424a952-09b0-484d-9c9e-9756404c3123/snapshot_date=2023-12-26/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0427eabb-7fa2-4b94-a21e-e3b1def3551d/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0427eabb-7fa2-4b94-a21e-e3b1def3551d/snapshot_date=2019-04-06/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=04312d72-8912-41b0-bda1-0b95128e009f/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=04312d72-8912-41b0-bda1-0b95128e009f/snapshot_date=2015-12-17/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=04314ad0-7305-4130-a6c1-6215e53b3363/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=04314ad0-7305-4130-a6c1-6215e53b3363/snapshot_date=2023-04-25/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=04318eeb-f459-4152-b799-102d9da93d88/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=04318eeb-f459-4152-b799-102d9da93d88/snapshot_date=2017-01-17/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0439bd5d-e4ab-457b-87f1-03c593decfc2/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0439bd5d-e4ab-457b-87f1-03c593decfc2/snapshot_date=2016-02-16/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=044b7061-016a-4d9e-a2e1-97ec06241a09/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=044b7061-016a-4d9e-a2e1-97ec06241a09/snapshot_date=2018-01-28/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=04523a02-9113-4fb3-b112-12073ee0175a/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=04523a02-9113-4fb3-b112-12073ee0175a/snapshot_date=2016-05-05/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=046a33d9-6c18-45f2-8fa2-365d4e483e94/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=046a33d9-6c18-45f2-8fa2-365d4e483e94/snapshot_date=2021-06-03/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=04b7ac57-8fab-4271-b1bf-34a5335b48bb/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=04b7ac57-8fab-4271-b1bf-34a5335b48bb/snapshot_date=2018-10-06/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=04cd3b78-063a-42e8-a8ae-e215c9f70d77/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=04cd3b78-063a-42e8-a8ae-e215c9f70d77/snapshot_date=2020-04-30/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=04df6f4c-4ab8-4466-bdbe-d1e425929ae5/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=04df6f4c-4ab8-4466-bdbe-d1e425929ae5/snapshot_date=2018-05-25/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=053bd9e8-725e-4ba9-b285-2a28db89a605/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=053bd9e8-725e-4ba9-b285-2a28db89a605/snapshot_date=2018-10-19/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0541b22f-9a9b-434f-8629-ccda6b58e37b/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=0541b22f-9a9b-434f-8629-ccda6b58e37b/snapshot_date=2019-03-14/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=05425f0a-4070-4c17-bce2-33bca7019b12/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=05425f0a-4070-4c17-bce2-33bca7019b12/snapshot_date=2023-06-24/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=059008e4-bbef-463b-9743-5ee498b35aa5/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=059008e4-bbef-463b-9743-5ee498b35aa5/snapshot_date=2023-04-18/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=05977728-8ff5-4ebc-bbd3-77a42ada3940/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=05977728-8ff5-4ebc-bbd3-77a42ada3940/snapshot_date=2016-09-16/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=05ad64f7-e162-4dec-a775-473ec3c714ff/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=05ad64f7-e162-4dec-a775-473ec3c714ff/snapshot_date=2019-04-23/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=05afdca5-2fe4-497b-8c43-7a1eb48b30a1/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=05afdca5-2fe4-497b-8c43-7a1eb48b30a1/snapshot_date=2018-10-02/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=05c703f5-5d5c-4b6d-a593-136f602720fe/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=05c703f5-5d5c-4b6d-a593-136f602720fe/snapshot_date=2023-07-24/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=05df59c1-cb27-41c2-bd12-3fa7b847604d/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=05df59c1-cb27-41c2-bd12-3fa7b847604d/snapshot_date=2018-05-02/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=05e3aa79-c033-4dac-ae1e-0c5c3bdadedb/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=05e3aa79-c033-4dac-ae1e-0c5c3bdadedb/snapshot_date=2020-12-25/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=05f3b5f8-cd21-4c3a-87e9-47483129fbc1/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=05f3b5f8-cd21-4c3a-87e9-47483129fbc1/snapshot_date=2019-10-11/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp
#
# *** WARNING: max output size exceeded, skipping output. ***
#
# y/edp_run_id=fa487947-a4ae-4ba4-97b1-7661b0a88256/snapshot_date=2024-04-14/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fa857298-e901-4dcb-b550-8166fbc143fb/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fa857298-e901-4dcb-b550-8166fbc143fb/snapshot_date=2017-05-17/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fa8ceefa-ca68-4562-b671-d63e2588a2fc/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fa8ceefa-ca68-4562-b671-d63e2588a2fc/snapshot_date=2018-08-17/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=faaeeaf0-9a3e-4b44-8884-195f9a49c763/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=faaeeaf0-9a3e-4b44-8884-195f9a49c763/snapshot_date=2022-01-02/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=facbe1d0-a085-4875-aa44-895dfdc4b6d6/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=facbe1d0-a085-4875-aa44-895dfdc4b6d6/snapshot_date=2021-08-31/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=facc89ec-8aa0-421d-9be4-3db274b0fe4d/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=facc89ec-8aa0-421d-9be4-3db274b0fe4d/snapshot_date=2019-06-08/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fad047dd-e013-413b-a1d0-1aa69cc7d93f/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fad047dd-e013-413b-a1d0-1aa69cc7d93f/snapshot_date=2020-10-07/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fad45768-6937-4a15-9e31-64c380a7054a/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fad45768-6937-4a15-9e31-64c380a7054a/snapshot_date=2022-11-14/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=faf33ff0-37c6-4e53-ba90-910672fe6132/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=faf33ff0-37c6-4e53-ba90-910672fe6132/snapshot_date=2015-01-11/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=faf88640-20b0-4c5d-aa4e-01ebb8a20368/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=faf88640-20b0-4c5d-aa4e-01ebb8a20368/snapshot_date=2023-06-04/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fb3f45c6-c704-4536-85f5-050a8afa0aaf/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fb3f45c6-c704-4536-85f5-050a8afa0aaf/snapshot_date=2017-06-04/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fb45f57a-225e-4c09-8673-593d36f98568/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fb45f57a-225e-4c09-8673-593d36f98568/snapshot_date=2020-11-18/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fb5683c9-7f26-4c7f-8d5d-ae2fc437fee2/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fb5683c9-7f26-4c7f-8d5d-ae2fc437fee2/snapshot_date=2024-04-23/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fb5771e7-f2ed-420a-bcee-27c0c192720c/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fb5771e7-f2ed-420a-bcee-27c0c192720c/snapshot_date=2017-08-28/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fb5992d6-adb4-493d-aca7-684f98ffcbdf/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fb5992d6-adb4-493d-aca7-684f98ffcbdf/snapshot_date=2019-08-07/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fb6b7b47-e6c6-416f-9aec-aef5d2d0c566/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fb6b7b47-e6c6-416f-9aec-aef5d2d0c566/snapshot_date=2021-01-30/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fb780243-39ab-4a00-9881-1a6c133e374f/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fb780243-39ab-4a00-9881-1a6c133e374f/snapshot_date=2016-01-29/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fb9ea40d-b626-46d2-ad35-b02cbfc93062/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fb9ea40d-b626-46d2-ad35-b02cbfc93062/snapshot_date=2019-11-27/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fbcc4745-2067-473d-86b5-c0ac7f36f7ff/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fbcc4745-2067-473d-86b5-c0ac7f36f7ff/snapshot_date=2022-03-15/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fbd8c371-8556-4e54-9080-086637814df7/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fbd8c371-8556-4e54-9080-086637814df7/snapshot_date=2015-01-16/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fc41a732-a9cc-4aeb-9d54-ebe5087e5080/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fc41a732-a9cc-4aeb-9d54-ebe5087e5080/snapshot_date=2020-03-22/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fc510f63-8b60-41c9-8481-97fa3b7a69f5/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fc510f63-8b60-41c9-8481-97fa3b7a69f5/snapshot_date=2022-11-11/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fc5b353c-9131-4720-9970-6fbe5d78ecff/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fc5b353c-9131-4720-9970-6fbe5d78ecff/snapshot_date=2022-01-22/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fc602beb-853c-4d8d-a0d1-d475a86847db/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fc602beb-853c-4d8d-a0d1-d475a86847db/snapshot_date=2018-05-09/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fc8911bc-a82c-462d-a3d5-ca0249637fcb/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fc8911bc-a82c-462d-a3d5-ca0249637fcb/snapshot_date=2023-09-12/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fc8df448-ece0-4212-8f0b-ae2a9f432ec4/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fc8df448-ece0-4212-8f0b-ae2a9f432ec4/snapshot_date=2018-07-16/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fc94dd97-1778-4062-9c2a-9df61a810029/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fc94dd97-1778-4062-9c2a-9df61a810029/snapshot_date=2016-09-27/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fcb06aaa-9dbc-4646-a9f4-079d7fad62af/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fcb06aaa-9dbc-4646-a9f4-079d7fad62af/snapshot_date=2019-09-24/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fcb2d301-9774-4445-8dc9-b63d0e04ff36/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fcb2d301-9774-4445-8dc9-b63d0e04ff36/snapshot_date=2020-04-11/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fccae3ec-43a4-496f-9289-3049151883e3/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fccae3ec-43a4-496f-9289-3049151883e3/snapshot_date=2020-04-17/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fcd829a2-012d-4a2e-a8a3-24d0d80aa099/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fcd829a2-012d-4a2e-a8a3-24d0d80aa099/snapshot_date=2022-03-22/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fd236cfc-4e12-4833-9e82-041779dd21b7/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fd236cfc-4e12-4833-9e82-041779dd21b7/snapshot_date=2019-07-10/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fd258de6-5b09-4e57-b249-cb80a901bd57/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fd258de6-5b09-4e57-b249-cb80a901bd57/snapshot_date=2016-04-14/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fd30bec3-f4e6-4e08-9064-2cc0eb4ac592/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fd30bec3-f4e6-4e08-9064-2cc0eb4ac592/snapshot_date=2023-04-02/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fd317feb-2225-4969-8fad-f8bb90de1efc/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fd317feb-2225-4969-8fad-f8bb90de1efc/snapshot_date=2016-05-30/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fd4538e7-23f7-47bc-9b0b-f148da8f6951/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fd4538e7-23f7-47bc-9b0b-f148da8f6951/snapshot_date=2016-04-24/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fd4708ef-d0a8-4149-b9e2-3603b42ee715/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fd4708ef-d0a8-4149-b9e2-3603b42ee715/snapshot_date=2018-07-13/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fd5281a0-314d-45f4-8711-372529af1aab/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fd5281a0-314d-45f4-8711-372529af1aab/snapshot_date=2023-09-10/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fd5b808b-5156-41fb-b655-c2e4e7d0aa8f/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fd5b808b-5156-41fb-b655-c2e4e7d0aa8f/snapshot_date=2021-11-20/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fd5e8a72-ab82-405d-803f-4ace3cb39ffb/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fd5e8a72-ab82-405d-803f-4ace3cb39ffb/snapshot_date=2019-12-17/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fd6067b0-4a3f-4f69-8f05-24776e1504d3/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fd6067b0-4a3f-4f69-8f05-24776e1504d3/snapshot_date=2023-05-15/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fd62dd4f-71ba-4b88-8e97-19cd8b1ab52d/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fd62dd4f-71ba-4b88-8e97-19cd8b1ab52d/snapshot_date=2015-11-20/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fd7bd5b0-d955-4402-8f29-4eeb44bd22b2/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fd7bd5b0-d955-4402-8f29-4eeb44bd22b2/snapshot_date=2018-02-03/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fda41d50-9fd4-4281-b5ed-c4a1b73ed4fa/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fda41d50-9fd4-4281-b5ed-c4a1b73ed4fa/snapshot_date=2016-07-18/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fda86713-bbe2-4cf6-9416-b2debd40daa7/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fda86713-bbe2-4cf6-9416-b2debd40daa7/snapshot_date=2018-07-03/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fda96d2d-0ca1-407d-9a3b-f65e725c02ee/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fda96d2d-0ca1-407d-9a3b-f65e725c02ee/snapshot_date=2016-12-20/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fdaee420-05d6-4460-bd97-20c87596ad8a/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fdaee420-05d6-4460-bd97-20c87596ad8a/snapshot_date=2016-12-04/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fdc2476e-c2c6-4143-b7d0-653987f74043/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fdc2476e-c2c6-4143-b7d0-653987f74043/snapshot_date=2019-08-26/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fdd1c7ea-7d8f-44f6-ad8c-f9ca82750139/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fdd1c7ea-7d8f-44f6-ad8c-f9ca82750139/snapshot_date=2019-04-15/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fde3cf25-270d-4907-8a94-7700890b7566/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fde3cf25-270d-4907-8a94-7700890b7566/snapshot_date=2022-11-15/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fdfcb4c2-9bb2-401c-aa22-4e42b6d13a13/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fdfcb4c2-9bb2-401c-aa22-4e42b6d13a13/snapshot_date=2018-08-30/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fdfec59c-2c7a-463e-a47a-0347b29d0a4c/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fdfec59c-2c7a-463e-a47a-0347b29d0a4c/snapshot_date=2023-02-10/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fe20e4cc-a1fd-4126-9286-eca52fc71576/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fe20e4cc-a1fd-4126-9286-eca52fc71576/snapshot_date=2016-10-27/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fe32bb2b-bf0b-4942-bec1-6bc6765a89f8/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fe32bb2b-bf0b-4942-bec1-6bc6765a89f8/snapshot_date=2020-07-27/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fe383be3-1a77-4415-a4b9-85408b433db2/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fe383be3-1a77-4415-a4b9-85408b433db2/snapshot_date=2023-12-07/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fe68f757-c2d1-4f5e-9510-21eeff12eacf/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fe68f757-c2d1-4f5e-9510-21eeff12eacf/snapshot_date=2016-07-07/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fe75c90d-12b9-4cca-916e-81959e315667/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fe75c90d-12b9-4cca-916e-81959e315667/snapshot_date=2024-02-23/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fe995f13-4873-45e7-86f4-0ea1450f8bcf/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=fe995f13-4873-45e7-86f4-0ea1450f8bcf/snapshot_date=2022-03-16/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=feae8c21-c786-4da7-b1d4-d3404fb0764b/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=feae8c21-c786-4da7-b1d4-d3404fb0764b/snapshot_date=2023-04-13/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=feb7ce49-44dd-4fc1-8e14-3a529a84ea54/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=feb7ce49-44dd-4fc1-8e14-3a529a84ea54/snapshot_date=2021-01-19/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=feed0ad0-9f14-48ea-83ce-306eb09d290c/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=feed0ad0-9f14-48ea-83ce-306eb09d290c/snapshot_date=2015-10-13/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=ff16cdab-0b35-4d03-b6e4-e9e545960e14/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=ff16cdab-0b35-4d03-b6e4-e9e545960e14/snapshot_date=2015-01-07/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=ff1f635e-1413-4e87-bcfe-5addd18284c3/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=ff1f635e-1413-4e87-bcfe-5addd18284c3/snapshot_date=2024-02-12/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=ff2749e8-a9f0-4322-ae13-b43abbca5e0a/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=ff2749e8-a9f0-4322-ae13-b43abbca5e0a/snapshot_date=2023-03-16/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=ff4174e0-fbb3-41bf-91ad-a6304b2aed14/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=ff4174e0-fbb3-41bf-91ad-a6304b2aed14/snapshot_date=2015-03-21/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=ff545efe-ca31-43e7-854b-7226df26d34f/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=ff545efe-ca31-43e7-854b-7226df26d34f/snapshot_date=2021-07-28/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=ff65a6e3-a73f-4154-84b4-883ba66fd560/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=ff65a6e3-a73f-4154-84b4-883ba66fd560/snapshot_date=2019-07-31/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=ff79e664-ebe8-46b0-aa52-28eb89b92c08/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=ff79e664-ebe8-46b0-aa52-28eb89b92c08/snapshot_date=2023-05-12/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=ff9eb4dd-53d5-4cba-b038-a005b86193a2/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=ff9eb4dd-53d5-4cba-b038-a005b86193a2/snapshot_date=2021-05-30/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=ffb2d001-6026-4e7c-8594-bc5ecb98ad7b/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=ffb2d001-6026-4e7c-8594-bc5ecb98ad7b/snapshot_date=2017-09-28/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=ffc1f06a-966d-4d4c-9106-8a2d21d27ca2/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=ffc1f06a-966d-4d4c-9106-8a2d21d27ca2/snapshot_date=2016-08-03/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=ffc27ec6-fa07-4674-9256-c96d716b0771/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=ffc27ec6-fa07-4674-9256-c96d716b0771/snapshot_date=2022-06-04/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=ffe3b578-833c-44b1-b9a6-119da2058d57/
# s3://app-id-89055-dep-id-109792-uu-id-n6ph64imx36e/trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/edp_run_id=ffe3b578-833c-44b1-b9a6-119da2058d57/snapshot_date=2018-01-12/
# 2023-09-04 15:48:44
# 212001
# Processing dataset completed for: trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/
# Inventory table processing completed for : ['trusted/analytics/data_dlvr/lda_taser_txns_shrt_wndw_daily/']

# %%
from pyspark.sql import functions as F
from pyspark.sql.types import StructType, StructField, StringType, LongType, DoubleType
import math

# Initialize Delta table for candidate operations
candidate_table_delta = DeltaTable.forName(spark, candidate_table)

for prefix in prefixes:
    print(f"Processing candidate table for prefix: {prefix}")
    
    try:
        # Read inventory and filter by prefix with load_status IS NULL
        df = spark.sql(f"""
            SELECT s3_bucket_name, bucket_prefix, key, extension, size 
            FROM {s3_inventory_table}
            WHERE bucket_prefix = '{prefix}' AND load_status IS NULL
        """)
        
        # Skip if no unprocessed records
        if df.count() == 0:
            print(f"No records with null load_status for {prefix}")
            continue
        
        # Filter for structured files
        #STRUCTURED_EXTS = [".parquet"]
        #structured_list = [e.lstrip('.').lower() for e in STRUCTURED_EXTS]
        df_structured = df.filter(col("extension").isNotNull())
        display(df_structured)
        # Extract s3_bucket_name and table name
        s3_bucket_name = df.select("s3_bucket_name").first()[0]
        table_name = os.path.basename(os.path.normpath(prefix))
        
        # Validate bucket and prefix
        if not s3_bucket_name or not prefix:
            print(f"ERROR: Invalid bucket or prefix")
            continue
        
        # Calculate metrics from inventory table (fresh counts)
        total_file_count = df.count()
        structured_file_count = df_structured.count()
        total_size_bytes = df.agg(sum("size")).collect()[0][0] or 0
        table_file_size_mb = total_size_bytes / (1024 * 1024)
        
        # Handle edge cases
        if math.isnan(table_file_size_mb) or math.isinf(table_file_size_mb):
            table_file_size_mb = 0.0
        table_file_size_mb = round(table_file_size_mb, 2)
        
        print(f"Metrics calculated:")
        print(f"   Total files: {total_file_count}")
        print(f"   Structured files: {structured_file_count}")
        print(f"   Total size: {table_file_size_mb:.2f} MB")
        
        # Check if record exists
        existing_candidate = spark.table(candidate_table).filter(
            (col("s3_bucket_name") == s3_bucket_name) &
            (col("bucket_prefix") == prefix) &
            (col("candidate_for_managed_table_creation").isNull())
        )
        
        existing_count = existing_candidate.count()
        
        if existing_count > 0:
            # UPDATE existing record
            print(f"Updating existing candidate record for {prefix}")
            
            # Create source DataFrame with explicit schema
            source_schema = StructType([
                StructField("s3_bucket_name", StringType(), False),
                StructField("bucket_prefix", StringType(), False),
                StructField("new_total_file_count", LongType(), False),
                StructField("new_table_file_size_mb", DoubleType(), False),
                StructField("new_structured_file_count", LongType(), False)
            ])
            
            source_data = [(
                s3_bucket_name,
                prefix,
                int(total_file_count),
                float(table_file_size_mb),
                int(structured_file_count)
            )]
            
            source_df = spark.createDataFrame(source_data, schema=source_schema)
            
            candidate_table_delta.alias("t").merge(
                source_df.alias("s"),
                """t.s3_bucket_name = s.s3_bucket_name 
                   AND t.bucket_prefix = s.bucket_prefix 
                   AND t.candidate_for_managed_table_creation IS NULL"""
            ).whenMatchedUpdate(
                set={
                    "total_file_count": "s.new_total_file_count",
                    "table_file_size_mb": "s.new_table_file_size_mb",
                    "structured_file_count": "s.new_structured_file_count"
                }
            ).execute()
            
            print(f"Successfully updated candidate record for {prefix}")
        else:
            # LOGIC 2: INSERT new record
            print(f"Inserting new candidate record for {prefix}")
            
            # Get the exact schema from the candidate table
            candidate_table_df = spark.table(candidate_table)
            candidate_schema = candidate_table_df.schema
            
            # Create a row with all columns from the schema
            row_data = {}
            for field in candidate_schema.fields:
                if field.name == "execution_id":
                    row_data[field.name] = execution_id
                elif field.name == "s3_bucket_name":
                    row_data[field.name] = s3_bucket_name
                elif field.name == "bucket_prefix":
                    row_data[field.name] = prefix
                elif field.name == "table_name":
                    row_data[field.name] = table_name
                elif field.name == "total_file_count":
                    row_data[field.name] = int(total_file_count)
                elif field.name == "table_file_size_mb":
                    row_data[field.name] = float(table_file_size_mb)
                elif field.name == "structured_file_count":
                    row_data[field.name] = int(structured_file_count)
                elif field.name == "candidate_for_managed_table_creation":
                    row_data[field.name] = None
                else:
                    # Set default value for any other columns
                    row_data[field.name] = None
            
            # Create DataFrame with exact schema
            new_candidate_df = spark.createDataFrame([row_data], schema=candidate_schema)
            
            new_candidate_df.write \
                .format("delta") \
                .mode("append") \
                .saveAsTable(candidate_table)
            
            print(f"Successfully inserted candidate record for {prefix}")
        
        print(f"Completed candidate processing for {prefix}\n")
        
    except Exception as e:
        print(f"ERROR processing candidate for {prefix}:")
        print(f"Error: {str(e)}")
        import traceback
        traceback.print_exc()
        continue

print("Candidate table processing completed!")
# Out:
# Candidate table processing completed!

# %%
try:
    if file_exists_in_volume(f"{dataset_mapping_file_location}/{dataset_mapping_file}"):
        archive_file_name=dataset_mapping_file.replace(".csv",f"_{execution_id}.csv")
        source_path=f"{dataset_mapping_file_location}/{dataset_mapping_file}"
        archive_path=f"{archive_dataset_mapping_file_location}/{archive_file_name}"
        dbutils.fs.mv(source_path,archive_path)
        # dbutils.fs.cp(source_path,archive_path)
        # dbutils.fs.rm(source_path)
except Exception as e:
    print (f"{e}")
