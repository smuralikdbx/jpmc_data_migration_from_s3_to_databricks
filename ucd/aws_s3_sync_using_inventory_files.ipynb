# %%
import uuid
from pyspark.sql.functions import pandas_udf, explode, udf,from_json
from pyspark.sql.types import ArrayType, StringType, DoubleType
import json
from pyspark.sql.functions import struct, flatten, lit, col,row_number, current_timestamp
from pyspark.sql import functions as F
from typing import Iterator, Tuple
import pandas as pd

from pyspark.sql.types import StructType, StructField, StringType, TimestampType, BooleanType
from datetime import datetime
from pyspark.sql import Window
import time
import threading
from concurrent.futures import ProcessPoolExecutor, as_completed,ThreadPoolExecutor
from multiprocessing import cpu_count
import concurrent.futures

# %%
dbutils.widgets.text("catalog", "users")
dbutils.widgets.text("schema", "dom_rodrigues")
dbutils.widgets.text("max_workers", "4", "Max Workers")

dbutils.widgets.dropdown("debug", "true", ["true", "false"])
dbutils.widgets.text("runId", "")
dbutils.widgets.text("s3_batch_copy_id", "Test1", "Batch Copy Id to sync")
dbutils.widgets.text("dbutils_thread_pool_size", "80", "DBUtils Thread Pool Size")

catalog = dbutils.widgets.get("catalog")
schema =  dbutils.widgets.get("schema")
runId =  dbutils.widgets.get("runId")

runId = str(uuid.uuid4()) if len(runId.strip()) == 0 else runId

s3_batch_copy_id=dbutils.widgets.get("s3_batch_copy_id")
max_workers = int(dbutils.widgets.get("max_workers"))
dbutils_thread_pool_size  = int(dbutils.widgets.get("dbutils_thread_pool_size"))

debug =  True if dbutils.widgets.get("debug") == 'true' else False
trace = False
createMetadataTables = False

spark.sql(f"use {catalog}.{schema}")
# Out:
# DataFrame[]

# %%
missing_files_df = spark.sql(f"""
    select recon.*
    from {catalog}.{schema}.ucd_src_dest_mapping mapping
    join {catalog}.{schema}.ucd_s3_inventory_recon recon 
    on mapping.s3_batch_copy_id = recon.s3_batch_copy_id and mapping.runId = recon.runId
    and mapping.enabled= True
    and mapping.s3_batch_copy_id = '{s3_batch_copy_id}'
    and recon.status = 'EXISTS_IN_SRC_AND_BUT_NOT_IN_DEST'
""")

missing_files_df.limit(10).display() if trace else None

# %%
# The operation is parallelized by first recursively listing the objects in the source directory using a thread pool on the driver and subsequently launching a Spark job to perform the individual operations.

spark.conf.set("spark.databricks.service.dbutils.fs.parallel.enabled", True)
spark.conf.set("spark.databricks.service.dbutils.fs.parallel.ls.threadPoolSize", dbutils_thread_pool_size) #default 20
#spark.conf.set("spark.databricks.service.dbutils.fs.parallel.ls.timeoutSeconds", 7200)

# %%
s3prefix = "s3://"
missing_files_df_copy = missing_files_df.select(F.concat(F.lit(s3prefix), col("src_bucket"), F.lit("/") , col("src_prefix"), col("Key")).alias("src_key"),
                        F.concat(F.lit(s3prefix), col("dest_bucket_name"), F.lit("/"),col("dest_prefix"), col("Key")).alias("dest_key"),
                        F.when(col("Key").endswith("/"), F.lit("dir")).otherwise(F.lit("file")).alias("type"))

missing_files_df_copy.limit(10).display() if trace else None

# %%
new_paths_to_copy_pd_df_all = missing_files_df_copy.toPandas()
indexed_files = [(row['src_key'], row['dest_key'], row['type'], i+1, new_paths_to_copy_pd_df_all.shape[0]) for i, row in enumerate(new_paths_to_copy_pd_df_all.to_records(index=False))]

# %%
print(f"Starting sync process for {s3_batch_copy_id} using runId {runId}")
# Out:
# Starting sync process for Test1 using runId c79863a1-6f67-44dc-a31f-f99f1c001ed2

# %%
def copy_files(args):
    start_time = time.time()
    src_path, dest_path, file_type, file_index, total_files_len = args

    try: 
        print(f"\nCopying {src_path} to {dest_path} ") if debug else None
        dbutils.fs.cp(src_path, dest_path, recurse=True if file_type == 'dir' else False)
        print(f"SUCCESS -  {src_path} copied, {file_index} /{total_files_len} completed.  Duration: {time.time() -start_time}") if debug else None
    except Exception as e:
        print(f"Exception {e}")
        print(f"🚨 FAILED - {file_index} /{total_files_len} completed.  Duration: {time.time() -start_time}")

# %%
#Let's do this sequentially to avoid potential data overwrites  (duplicate writes ok for now). Some intelligence can be built in to do this in parallel
start_time = time.time()
for args in indexed_files:
    copy_files(args)
    
total_time = time.time() - start_time
print(f"📊 Total time: {total_time:.1f} seconds ({total_time/60:.1f} minutes)")
# Out:
# Copying s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-16_21-43-18/ to s3://databricks-e2demofieldengwest/dom_rodrigues/folder_2/XGBoostTrainer_2025-07-16_21-43-18/
# SUCCESS -  s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-16_21-43-18/ copied, 1 /44 completed.  Duration: 1.790578842163086
#
# Copying s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-16_21-43-19/ to s3://databricks-e2demofieldengwest/dom_rodrigues/folder_2/XGBoostTrainer_2025-07-16_21-43-19/
# SUCCESS -  s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-16_21-43-19/ copied, 2 /44 completed.  Duration: 1.122368574142456
#
# Copying s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-16_21-43-42/ to s3://databricks-e2demofieldengwest/dom_rodrigues/folder_2/XGBoostTrainer_2025-07-16_21-43-42/
# SUCCESS -  s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-16_21-43-42/ copied, 3 /44 completed.  Duration: 1.0117173194885254
#
# Copying s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-16_21-44-32/ to s3://databricks-e2demofieldengwest/dom_rodrigues/folder_2/XGBoostTrainer_2025-07-16_21-44-32/
# SUCCESS -  s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-16_21-44-32/ copied, 4 /44 completed.  Duration: 1.0098011493682861
#
# Copying s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-16_21-45-32/ to s3://databricks-e2demofieldengwest/dom_rodrigues/folder_2/XGBoostTrainer_2025-07-16_21-45-32/
# SUCCESS -  s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-16_21-45-32/ copied, 5 /44 completed.  Duration: 0.9582395553588867
#
# Copying s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-16_21-46-02/ to s3://databricks-e2demofieldengwest/dom_rodrigues/folder_2/XGBoostTrainer_2025-07-16_21-46-02/
# SUCCESS -  s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-16_21-46-02/ copied, 6 /44 completed.  Duration: 0.9979972839355469
#
# Copying s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-16_21-48-54/ to s3://databricks-e2demofieldengwest/dom_rodrigues/folder_2/XGBoostTrainer_2025-07-16_21-48-54/
# SUCCESS -  s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-16_21-48-54/ copied, 7 /44 completed.  Duration: 1.1874582767486572
#
# Copying s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-17_21-11-12/ to s3://databricks-e2demofieldengwest/dom_rodrigues/folder_2/XGBoostTrainer_2025-07-17_21-11-12/
# SUCCESS -  s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-17_21-11-12/ copied, 8 /44 completed.  Duration: 1.0019309520721436
#
# Copying s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-17_21-11-17/ to s3://databricks-e2demofieldengwest/dom_rodrigues/folder_2/XGBoostTrainer_2025-07-17_21-11-17/
# SUCCESS -  s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-17_21-11-17/ copied, 9 /44 completed.  Duration: 1.1905477046966553
#
# Copying s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-17_21-11-18/ to s3://databricks-e2demofieldengwest/dom_rodrigues/folder_2/XGBoostTrainer_2025-07-17_21-11-18/
# SUCCESS -  s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-17_21-11-18/ copied, 10 /44 completed.  Duration: 1.2600297927856445
#
# Copying s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-17_21-11-41/ to s3://databricks-e2demofieldengwest/dom_rodrigues/folder_2/XGBoostTrainer_2025-07-17_21-11-41/
# SUCCESS -  s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-17_21-11-41/ copied, 11 /44 completed.  Duration: 1.1502861976623535
#
# Copying s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-17_21-15-14/ to s3://databricks-e2demofieldengwest/dom_rodrigues/folder_2/XGBoostTrainer_2025-07-17_21-15-14/
# SUCCESS -  s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-17_21-15-14/ copied, 12 /44 completed.  Duration: 0.9984498023986816
#
# Copying s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-17_21-58-17/ to s3://databricks-e2demofieldengwest/dom_rodrigues/folder_2/XGBoostTrainer_2025-07-17_21-58-17/
# SUCCESS -  s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-17_21-58-17/ copied, 13 /44 completed.  Duration: 1.1447515487670898
#
# Copying s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-24_12-59-47/ to s3://databricks-e2demofieldengwest/dom_rodrigues/folder_2/XGBoostTrainer_2025-07-24_12-59-47/
# SUCCESS -  s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-24_12-59-47/ copied, 14 /44 completed.  Duration: 0.9364097118377686
#
# Copying s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-24_12-59-56/ to s3://databricks-e2demofieldengwest/dom_rodrigues/folder_2/XGBoostTrainer_2025-07-24_12-59-56/
# SUCCESS -  s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-24_12-59-56/ copied, 15 /44 completed.  Duration: 1.5713074207305908
#
# Copying s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-24_13-00-12/ to s3://databricks-e2demofieldengwest/dom_rodrigues/folder_2/XGBoostTrainer_2025-07-24_13-00-12/
# SUCCESS -  s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-24_13-00-12/ copied, 16 /44 completed.  Duration: 1.106954574584961
#
# Copying s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-24_13-00-39/ to s3://databricks-e2demofieldengwest/dom_rodrigues/folder_2/XGBoostTrainer_2025-07-24_13-00-39/
# SUCCESS -  s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-24_13-00-39/ copied, 17 /44 completed.  Duration: 0.9509222507476807
#
# Copying s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-24_13-01-10/ to s3://databricks-e2demofieldengwest/dom_rodrigues/folder_2/XGBoostTrainer_2025-07-24_13-01-10/
# SUCCESS -  s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-24_13-01-10/ copied, 18 /44 completed.  Duration: 0.9860293865203857
#
# Copying s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-24_13-01-22/ to s3://databricks-e2demofieldengwest/dom_rodrigues/folder_2/XGBoostTrainer_2025-07-24_13-01-22/
# SUCCESS -  s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-24_13-01-22/ copied, 19 /44 completed.  Duration: 1.0577266216278076
#
# Copying s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-24_13-01-29/ to s3://databricks-e2demofieldengwest/dom_rodrigues/folder_2/XGBoostTrainer_2025-07-24_13-01-29/
# SUCCESS -  s3://databricks-e2demofieldengwest/dom_rodrigues/folder_1/XGBoostTrainer_2025-07-24_13